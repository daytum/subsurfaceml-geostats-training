# %% [markdown]
# <p align="center">
#     <img src="https://github.com/GeostatsGuy/GeostatsPy/blob/master/TCG_color_logo.png?raw=true" width="220" height="240" />
#
# </p>
#
# ## Subsurface Data Analytics
#
# ## Artificial Neural Networks for Prediction in Python
#
# #### Michael Pyrcz, Associate Professor, University of Texas at Austin
#
# ##### [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1) | [GeostatsPy](https://github.com/GeostatsGuy/GeostatsPy)
#
# #### Honggeun Jo, Graduate Student, The University of Texas at Austin
#
# ##### [LinkedIn](https://www.linkedin.com/in/honggeun-jo/?originalSubdomain=kr) | [Twitter](https://twitter.com/HonggeunJ)
#
# #### Wen Pan, Graduate Student, The University of Texas at Austin
#
# #### Eduardo Maldonado-Cruz, Graduate Student, The University of Texas at Austin
#
#
# ### PGE 383 Exercise: Artificial Neural Networks for Subsurface Modeling in Python
#
# Here's a simple workflow, demonstration of artificial neural networks for subsurface modeling workflows. This should help you get started with building subsurface models that use data analytics and machine learning. Here's some basic details about neural networks.
#
# #### Neural Networks
#
# Machine learning method for supervised learning for classification and regression analysis.  Here are some key aspects of support vector machines.
#
# **Basic Design** *"...a computing system made up of a number of simple, highly interconnected processing elements, which process information by their dynamic state response to external inputs."* Caudill (1989).
#
# **Nature-inspire Computing** based on the neuronal structure in the brain, including many interconnected simple, processing units, known as nodes that are capable of complicated emergent pattern detection due to a large number of nodes and interconnectivity.
#
# **Training and Testing** just like and other predictive model (e.g. linear regression, decision trees and support vector machines) we perform training to fit parameters and testing to tune hyperparameters.  Here we observe the error with training and testing datasets, but do not demonstrate tuning of the hyperparameters.
#
# **Parameters** are the weights applied to each connection and a bias term applied to each node.  For a single node in an artificial neural network, this includes the slope terms, $\beta_i$, and the bias term, $\beta_{0}$.
#
# \begin{equation}
# Y = \sum_{i=1}^m \beta_i X + \beta_0
# \end{equation}
#
# it can be seen that the number of parameters increases rapidly as we increase the number of nodes and the connectivity between the nodes.
#
# **Layers** the typical artificial neural net is structured with an **input layer**, with one node for each $m$ predictor feature, $X_1,\ldots,X_m$. There is an **ouput layer**, with one node for each $r$ response feature, $Y_1,\ldots,Y_r$.  There may be one or more layers of nodes between the input and output layers, known as **hidden layer(s)**.
#
# **Connections** are the linkages between the nodes in adjacent layers.  For example, in a fully connected artificial neural network, all the input nodes are connected to all of the nodes in the first layer, then all of the nodes in the first layer are connected to the next layer and so forth. Each connection includes a weight parameter as indicated above.
#
# **Nodes** receive the weighted signal from the connected previous layer nodes, sum and then apply this result to the **activation** function in the node. Some example activation functions include:
#
# * **Binary** the node fires or not.  This is represented by a Heaviside step function.
#
# * **Identify** the input is passed to the output $f(x) = x$
#
# * **Linear** the node passes a signal that increases linearly with the weighted input.
#
# * **Logistic** also known as sigmoid or soft step $f(x) = \frac{1}{1+e^{-x}}$
#
# the node output is the nonlinear activiation function applied to the linearly weighted inputs. This is fed to all nodes in the next layer.
#
# **Training Cycles** - the presentation of a batch of data, forward application of the current prediction model to make estimates, calculation of error and then backpropagation of error to correct the artificial neural network parameters to reduce the error over all of the batches.
#
# **Batch** is the set of training data for each training cycle of forward prediction and back propagation of error, drawn to train for each iteration. There is a trade-off, a larger batch results in more computational time per iteration, but a more accurate estimate of the error to adjust the weights.  Smaller batches result in a nosier estimate of the error, but faster epochs, this results in faster learning and even possibly more robust models.
#
# **Epochs** - is a set of training cycles, batches covering all available training data.
#
# **Local Minimums** - if one calculated the error hypersurface over the range of model parameters it would be hyparabolic, there is a global minimium error solution.  But this error hyper surface is rough and it is possible to be stuck in a local minimum. **Learning Rate** and **Mommentum** coefficients are introduced to avoid getting stuck in local minimums.
#
# * **Mommentum** is a hyperparameter to control the use of information from the weight update over the last epoch for consideration in the current epoch.  This can be accomplished with an update vector, $v_i$, a mommentum parameter, $\alpha$, to calculate the current weight update, $v_{i+1}$ given the new update $\theta_{i+1}$.
#
# \begin{equation}
# v_{i+1} = \alpha v_i + \theta_{i+1}
# \end{equation}
#
# * **Learning Rate** is a hyperparameter that controls the adjustment of the weights in response to the gradient indicated by backpropagation of error
#
# ##### Applications to subsurface modeling
#
# We demonstrate the estimation of normal score transformed porosity from depth.  This would be useful for building a vertical trend model.
#
# * modeling the complicated relationship between porosity and depth.
#
# #### Limitations of Neural Network Estimation
#
# Since we demonstrate the use of an artificial neural network to estimate porosity from sparsely sampled data over depth, we should comment on limitations of our artificial neural networks for this estimation problem:
#
# * does not honor the well data
#
# * does not honor the histogram of the data
#
# * does not honor spatial correlation
#
# * does not honor the multivariate relationship
#
# * generally low interpretability models
#
# * requires a large number of data for effective training
#
# * high model complexity with high model variance
#
#
# #### Workflow Goals
#
# Learn the basics of machine learning in python to predict subsurface features. This includes:
#
# * Loading and visualizing sample data
# * Trying out neural nets
#
# #### Objective
#
# In the PGE 383: Subsurface Machine Learning Class, I want to provide hands-on experience with building subsurface modeling workflows. Python provides an excellent vehicle to accomplish this. I have coded a package called GeostatsPy with GSLIB: Geostatistical Library (Deutsch and Journel, 1998) functionality that provides basic building blocks for building subsurface modeling workflows.
#
# The objective is to remove the hurdles of subsurface modeling workflow construction by providing building blocks and sufficient examples. This is not a coding class per se, but we need the ability to 'script' workflows working with numerical methods.
#
# #### Getting Started
#
# Here's the steps to get setup in Python with the GeostatsPy package:
#
# 1. Install Anaconda 3 on your machine (https://www.anaconda.com/download/).
# 2. From Anaconda Navigator (within Anaconda3 group), go to the environment tab, click on base (root) green arrow and open a terminal.
# 3. In the terminal type: pip install geostatspy.
# 4. Open Jupyter and in the top block get started by copy and pasting the code block below from this Jupyter Notebook to start using the geostatspy functionality.
#
# You will need to copy the data file to your working directory.  They are available here:
#
# * Tabular data - 12_sample_data.csv found [here](https://github.com/GeostatsGuy/GeoDataSets/blob/master/12_sample_data.csv).
#
# There are exampled below with these functions. You can go here to see a list of the available functions, https://git.io/fh4eX, other example workflows and source code.
#
# #### Import Required Packages
#
# We will also need some standard packages. These should have been installed with Anaconda 3.

# %%
hide_warnings = True
import numpy as np                        # ndarrys for gridded data
import pandas as pd                       # DataFrames for tabular data
import os                                 # set working directory, run executables
import matplotlib.pyplot as plt           # for plotting
import seaborn as sns                     # for plotting
import warnings                           # supress warnings from seaborn pairplot
from sklearn.model_selection import train_test_split # train / test DatFrame split
import warnings
if hide_warnings == True:
    warnings.filterwarnings('ignore')

# %% [markdown]
# We will also need the following packages to train and test our artificial neural nets:
#
# * Tensorflow - open source machine learning, with Keras modulw - high level application programing interface (API) to build and train models
#
# More information is available at [tensorflow install](https://www.tensorflow.org/install).
#
# * This workflow was designed with tensorflow version > 2.0.
#
# To import Tensorflow, set memory growth and check your current version of tensorflow you could run the next block of code.

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

physical_devices = tf.config.list_physical_devices('GPU')

if len(physical_devices) > 1:
    tf.config.experimental.set_memory_growth(physical_devices[0], True) # use if memory errors while using GPU
print('TensorFlow version = ' + tf.__version__)                         # check the installed version of tensorflow

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
device_lib.list_local_devices()
# Out:
# TensorFlow version = 2.10.0
# Num GPUs Available:  0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4636589994176211493
#  xla_global_id: -1]

# %% [markdown]
# Let's import all of the tensorflow and keras methods that we will need in our workflow.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential  
from tensorflow.keras.layers import Dense, Activation, Dropout  
#from keras.models import Sequential, load_model            # use instead for older version of TensorFlow
#from keras.layers.core import Dense, Dropout, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras import backend as k

# %% [markdown]
# #### Set the working directory
#
# I always like to do this so I don't lose files and to simplify subsequent read and writes (avoid including the full address each time).

# %%
#os.chdir("c:/PGE383")

# %% [markdown]
# #### Loading Data
# Let's load the provided multivariate, spatial dataset '12_sample_data.csv'.  It is a comma delimited file with:
#
# * Depth ($m$)
# * Normal Score Porosity
#
# It is common to transform properties to standard normal for geostatistical workflows.
#
# We load it with the pandas 'read_csv' function into a data frame we called 'df' and then preview it to make sure it loaded correctly.
#
# **Python Tip: using functions from a package** just type the label for the package that we declared at the beginning:
#
# ```python
# import pandas as pd
# ```
#
# so we can access the pandas function 'read_csv' with the command:
#
# ```python
# pd.read_csv()
# ```
#
# but read csv has required input parameters. The essential one is the name of the file. For our circumstance all the other default parameters are fine. If you want to see all the possible parameters for this function, just go to the docs [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
#
# * The docs are always helpful
# * There is often a lot of flexibility for Python functions, possible through using various inputs parameters
#
# also, the program has an output, a pandas DataFrame loaded from the data.  So we have to specficy the name / variable representing that new object.
#
# ```python
# df = pd.read_csv("1D_Porosity.csv")
# ```
#
# Let's run this command to load the data and then look at the resulting DataFrame to ensure that we loaded it.

# %%
#df2 = pd.read_csv("1D_Porosity.csv")                    # read a .csv file in as a DataFrame  
df2 = pd.read_csv("https://raw.githubusercontent.com/GeostatsGuy/GeoDataSets/master/1D_Porosity.csv") # load the data from Dr. Pyrcz's github repository
df2.head()                                              # we could also use this command for a table preview
# Out:
#    Depth  Nporosity
# 0   0.25      -1.37
# 1   0.50      -2.08
# 2   0.75      -1.67
# 3   1.00      -1.16
# 4   1.25      -0.24

# %% [markdown]
# #### Data Normalization
#
# We must normalize the features before we apply them in an artificial neural network model. These are the motivations for this normalization:
#
# * remove impact of scale of different types of data (i.e., depth varies between $[0,10]$, but porosity only varies between $[-3,3.0]$).
#
# * activation functions in artificial neural networks are designed to be more sensive to values of nodes closer to 0.0 (i.e., results in higher gradient and improves backpropagation in training)
#
# Let's normalize each feature.
#
# * We apply the min max normalization by-hand to force both the predictor and response features to be bound $[-1,1]$.
#
# * It is easy to backtransform given we keep track of the original min and max values

# %%
depth_min = df2['Depth'].values.min(); depth_max = df2['Depth'].values.max()
Npor_min = df2['Nporosity'].values.min(); Npor_max = df2['Nporosity'].values.max()
df2['norm_Depth'] = (df2['Depth'] - depth_min)/(depth_max - depth_min) * 2 - 1
df2['norm_Nporosity'] = (df2['Nporosity'] - Npor_min)/(Npor_max - Npor_min) * 2 - 1
df2.head()
# Out:
#    Depth  Nporosity  norm_Depth  norm_Nporosity
# 0   0.25      -1.37   -1.000000       -0.679458
# 1   0.50      -2.08   -0.948718       -1.000000
# 2   0.75      -1.67   -0.897436       -0.814898
# 3   1.00      -1.16   -0.846154       -0.584650
# 4   1.25      -0.24   -0.794872       -0.169300

# %% [markdown]
# It is also a good idea to check the summary statistics.
#
# * All normalized features should now range from -1.0 to 1.0

# %%
df2.describe().transpose()
# Out:
#                 count          mean       std   min       25%           50%  \
# Depth            40.0  5.125000e+00  2.922613  0.25  2.687500  5.125000e+00
# Nporosity        40.0  2.225000e-02  0.992111 -2.08 -0.757500  1.400000e-01
# norm_Depth       40.0 -5.551115e-18  0.599510 -1.00 -0.500000 -5.551115e-17
# norm_Nporosity   40.0 -5.090293e-02  0.447906 -1.00 -0.402935  2.257336e-03
#
#                      75%    max
# Depth           7.562500  10.00
# Nporosity       0.742500   2.35
# norm_Depth      0.500000   1.00
# norm_Nporosity  0.274266   1.00

# %% [markdown]
# #### Separation of Training and Testing Data
#
# We also need to split our data into training / testing datasets so that we:
#
# * can train our artificial neural networks using the training data
#
# * while testing their performance with the withheld testing (validation) data.

# %%
X2 = df2.iloc[:,[0,2]]                        # extract the predictor feature - acoustic impedance
y2 = df2.iloc[:,[1,3]]                        # extract the response feature - porosity
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=73073)

# %% [markdown]
# #### Visualize the Dataset
#
# Let's visualize the train and test data split on a single scatter plot.
#
# * we want to make sure it is fair
#
# * ensure that the test samples are not clustered or too far away from the training data.
#
# We will look at the original data and normalized data, the input to the neural network.

# %%
plt.subplot(211)
plt.plot(X2_train['Depth'].values,y2_train['Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=0.4, label = "Train")
plt.plot(X2_test['Depth'].values,y2_test['Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=0.4, label = "Test")
plt.title('Standard Normal Porosity vs. Depth')
plt.xlabel('Z (m)')
plt.ylabel('NPorosity')
plt.legend()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=1.0, wspace=0.2, hspace=0.2)

plt.subplot(212)
plt.plot(X2_train['norm_Depth'].values,y2_train['norm_Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=0.4, label = "Train")
plt.plot(X2_test['norm_Depth'].values,y2_test['norm_Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=0.4, label = "Test")
plt.title('Normalized Standard Normal Porosity vs. Normalized Depth')
plt.xlabel('Normalized Z')
plt.ylabel('Normalized NPorosity')
plt.legend()

plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=1.5, wspace=0.2, hspace=0.3)
plt.show()

# %% [markdown]
# #### Specify the Prediction Locations
#
# Given this training and testing data, let's specify the prediction locations over the range of the observed depths at regularly spaced $nbins$ locations.

# %%
# Specify the prediction locations
nbins = 1000
depth_bins = np.linspace(depth_min, depth_max, nbins) # set the bins for prediction
norm_depth_bins = (depth_bins-depth_min)/(depth_max-depth_min)*2-1 # use normalized bins

# %% [markdown]
# #### Build and Train a Simple Neural Network
#
# For our first model we will build a simple model with:
#
# * 1 predictor feature - depth ($d$)
#
# * 1 responce feature - normal score porosity ($N\{\phi\}$)
#
# we will build a model to predict normal score porosity from depth over all locations in our model $\bf{u} \in AOI$.
#
# \begin{equation}
# N\{\phi(\bf{u})\} = \hat{f} (d(\bf{u}))
# \end{equation}
#
# and use this model to support the prediction of porosity between the wells.
#
# #### Design, Train and Test a Neural Network
#
# In the following code we use keras / tensorflow to:
#
# 1. **Design the Network** - we use a fully connected, feed forward neural network with one node in the input and output layers, to receive the normalized depth and output the normalized (normal score) porosity.  We found by trial and error, given the complexity of the dataset, that we required a significant network width (about 500 nodes) and a network depth of atleast 4 hidden layers.
#
#
# 2. **Select the Optimizer** - we selected the adam optimizer (Kingma and Ba, 2015).  This optimizer is computationally efficient and is well suited to problems with noisy data and sparse gradients. It is an extension of stochastic gradient descent with the addition of adaptive gradient algorithm that calculates per-parameter learning rates to improve learning with sparse gradients, and root mean square propopagation that sets the learning rate based on the recent magnitudes of the gradients for each parameter to improve performance with noisy data.  We include stochastic gradient descent for experimentation.
#
#     * we found a learning rate of 0.01 to 0.001 works well
#     * we found the rate of decay parameters of $\beta_1=0.9$ and $\beta_2=0.999$ performed well
#
#
# 3. **Compile the Machine** - specify the optimizer, loss function and the metric for model training.
#
#
# 4. **Train the Network** - fit / train the model parameters over a specified number of batch size within a specified number of epochs.  We specify the train and test normalized predictor and response features.
#
# Then we visualize the model in the original units.

# %%
# for repeatable results set all the random number seeds before training the ANN 
seed = 13013; repeatable = True
if repeatable == True:
    tf.random.set_seed(seed = seed)
    np.random.seed(seed = seed)
    tf.keras.utils.set_random_seed(42)
    tf.config.experimental.enable_op_determinism()
    
# Design the neural network
model_2 = Sequential([
    Dense(1, activation='linear', input_shape=(1,)),                  # input layer
    Dense(10, activation='relu'),
#    Dense(20, activation='relu'),                                    # uncomment these to add hidden layers
#    Dense(20, activation='relu'),
#    Dense(20, activation='relu'),
#    Dense(20, activation='relu'),
    Dense(1, activation='linear'),                                    # output layer
])

# Select the Optimizer
adam = Adam(learning_rate=0.003, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False) # adam optimizer
#sgd = keras.optimizers.SGD(lr=0.001, momentum=0.0, decay = 0.0, nesterov=False)  # stochastic gradient descent

# Compile the Machine
model_2.compile(optimizer=adam,loss='mse',metrics=['accuracy'])

# Train the Network
hist_2 = model_2.fit(X2_train['norm_Depth'], y2_train['norm_Nporosity'],
    batch_size=1,epochs=100,validation_data=(X2_test['norm_Depth'], y2_test['norm_Nporosity']),verbose = 0)

# Predict with the Network
pred_norm_Nporsity = model_2.predict(np.array(norm_depth_bins)) # predict with our ANN
pred_Nporosity = ((pred_norm_Nporsity + 1)/2*(Npor_max - Npor_min)+Npor_min)

# Plot the Model Predictions
plt.subplot(1,1,1)
plt.plot(depth_bins,pred_Nporosity,'black',linewidth=2)
plt.plot(X2_train['Depth'].values,y2_train['Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=1.0, label = "Train")
plt.plot(X2_test['Depth'].values,y2_test['Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=1.0, label = "Test")
plt.xlabel('Depth (m)')
plt.ylabel('Porosity (faction)')
plt.legend()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()
# Out:
# 32/32 [==============================] - 0s 840us/step

# %% [markdown]
# #### Evaluation of the Model
#
# For my specified artificial neural network design and optimization parameters I have a very flexible model to fit the data.
#
# * artificial neural networks live up to their designation as **Universal Function Approximators**
#
# Let's check the training curve, loss functions for our model over training and testing datasets.
#
# * **square loss** ($L_2$ loss) is the:
#
# \begin{equation}
# L_2 = \sum_{\bf{u}_{\alpha} \in AOI} \left(y(\bf{u}_{\alpha}) - \hat{f}(x_1(\bf{u}_{\alpha}),\ldots,x_m(\bf{u}_{\alpha})\right)
# \end{equation}
#
# * this is a measure of the inaccuracy over the available data
#
# We can see the progress of the model over epochs in reduction of training and testing error.
#
# * we can observe that the model matches the training data after about 200 epochs, but continues to improve up the 1,000 epochs

# %%
# Plot the Loss vs. Training Epoch 
plt.subplot(1,1,1)
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Loss function of Artificial Neural Net Example #2')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0,0.4)
plt.grid()
plt.tight_layout()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# #### Some Observations
#
# We performed a set of experiments and made the following observations that may help you experiment with the design and training of this artificial neural network. Each machine was trained over 1000 epochs with a batch size of 5.
#
# For a 1 $\times$ 100 $\times$ 100 $\times$ 1 neural network:
# * Learning Rate of 0.001 still converging at 1000 epochs, missing some features
# * Learning Rate of 0.1 - stuck in a local minum as a step function
#
# For a 1 $\times$ 500 $\times$ 500 $\times$ 1 neural network:
# * Learning Rate of 0.01 - 0.001 for a close fit to training data
# * Learning Rate of 0.1 - stuck in a local minimum as a line
# * Learning Rate of $\le$ 0.0001 still converging at 1000 epochs, missing some features
#
# For a 1 $\times$ 500 $\times$ 500 $\times$ 500 $\times$ 1 neural network:
# * Learning Rate of 0.01 - 0.001 for a close fit to training data
# * Learning Rate of 0.1 - stuck as a line
# * Learning Rate of $\le$ 0.0001 still converging at 1000 epochs, missing some features
#
# #### Visualizing the Neural Net
#
# There are some methods available to interogate the artificial neural net.
#
# * neural net summary
#
# * weights
#
# Here's the summary from our neural net.  It lists by layers the number of nodes and number of parameters.

# %%
model_2.summary()                                      # artificial neural network design and number of parameters
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
#  dense_1 (Dense)             (None, 30)                60
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1123 (4.39 KB)
# Trainable params: 1123 (4.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# We can also see the actual trained weights for each node in each layer.

# %%
for layer in model_2.layers:                            # weights for the trained artificial neural network
    g = layer.get_config()
    h = layer.get_weights()
    print(g)
    print(h)
    print('\n')
# Out:
# {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'batch_input_shape': (None, 1), 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# [array([[1.4126656]], dtype=float32), array([-0.00616476], dtype=float32)]
#
#
# {'name': 'dense_1', 'trainable': True, 'dtype': 'float32', 'units': 30, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# [array([
# Let's slow down the learning rate, decrease the learning rate decay and increase the number of Epochs.

# %%
model_3 = Sequential([
    Dense(100, activation='linear', input_shape=(1,)),                  # input layer
    Dense(50, activation='relu'),
    Dense(50, activation='relu'),
    Dense(50, activation='relu'), 
#     Dense(20, activation='relu'),                                    # uncomment these to add hidden layers
#     Dense(20, activation='relu'),
#     Dense(20, activation='relu'),
#     Dense(20, activation='relu'),
    Dense(1, activation='tanh'),                                     # output layer
])


adam = Adam(learning_rate=0.0001) # adam optimizer
#sgd = keras.optimizers.SGD(lr=0.001, momentum=0.0, decay = 0.0, nesterov=False)  # stochastic gradient descent

# Compile the Machine
model_3.compile(optimizer=adam,loss='mse',metrics=['accuracy'])

# Train the Network
hist3 = model_3.fit(X2_train['norm_Depth'].values, y2_train['norm_Nporosity'].values,
    batch_size=5, epochs=20000,validation_data=(X2_test['norm_Depth'], y2_test['norm_Nporosity']))
# Out:
# Epoch 1/20000
# 7/7 [==============================] - 1s 46ms/step - loss: 0.2310 - accuracy: 0.0000e+00 - val_loss: 0.0654 - val_accuracy: 0.0000e+00
# Epoch 2/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2273 - accuracy: 0.0000e+00 - val_loss: 0.0636 - val_accuracy: 0.0000e+00
# Epoch 3/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2233 - accuracy: 0.0000e+00 - val_loss: 0.0625 - val_accuracy: 0.0000e+00
# Epoch 4/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2207 - accuracy: 0.0000e+00 - val_loss: 0.0616 - val_accuracy: 0.0000e+00
# Epoch 5/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2179 - accuracy: 0.0000e+00 - val_loss: 0.0609 - val_accuracy: 0.0000e+00
# Epoch 6/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2156 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 7/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2133 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 8/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2113 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 9/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2083 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 10/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2065 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 11/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2049 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 12/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2031 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 13/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2014 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 14/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2003 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 15/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1984 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 16/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1971 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 17/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1958 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 18/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1943 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 19/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1935 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 20/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1921 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 21/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1911 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 22/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1899 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 23/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1889 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 24/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1879 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 25/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1869 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 26/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1856 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 27/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1842 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 28/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1834 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 29/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1828 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 30/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1819 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 31/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1809 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 32/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1800 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 33/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1799 - accuracy: 0.0000e+00 - val_loss: 0.0609 - val_accuracy: 0.0000e+00
# Epoch 34/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1787 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 35/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1773 - accuracy: 0.0000e+00 - val_loss: 0.0607 - val_accuracy: 0.0000e+00
# Epoch 36/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1766 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 37/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1755 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 38/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1747 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 39/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1738 - accuracy: 0.0000e+00 - val_loss: 0.0609 - val_accuracy: 0.0000e+00
# Epoch 40/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1731 - accuracy: 0.0000e+00 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 41/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.
20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0859 - accuracy: 0.0000e+00 - val_loss: 0.0728 - val_accuracy: 0.0000e+00
# Epoch 167/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0850 - accuracy: 0.0000e+00 - val_loss: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 168/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0845 - accuracy: 0.0000e+00 - val_loss: 0.0730 - val_accuracy: 0.0000e+00
# Epoch 169/20000
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0842 - accuracy: 0.0000e+00 - val_loss: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 170/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0833 - accuracy: 0.0000e+00 - val_loss: 0.0741 - val_accuracy: 0.0000e+00
# Epoch 171/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0835 - accuracy: 0.0000e+00 - val_loss: 0.0751 - val_accuracy: 0.0000e+00
# Epoch 172/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0829 - accuracy: 0.0000e+00 - val_loss: 0.0755 - val_accuracy: 0.0000e+00
# Epoch 173/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0828 - accuracy: 0.0000e+00 - val_loss: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 174/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0822 - accuracy: 0.0000e+00 - val_loss: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 175/20000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0820 - accuracy: 0.0000e+00 - val_loss: 0.0757 - val_accuracy: 0.0000e+00
# Epoch 176/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0818 - accuracy: 0.0000e+00 - val_loss: 0.0754 - val_accuracy: 0.0000e+00
# Epoch 177/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0819 - accuracy: 0.0000e+00 - val_loss: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 178/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.0000e+00 - val_loss: 0.0751 - val_accuracy: 0.0000e+00
# Epoch 179/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0806 - accuracy: 0.0000e+00 - val_loss: 0.0757 - val_accuracy: 0.0000e+00
# Epoch 180/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0816 - accuracy: 0.0000e+00 - val_loss: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 181/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0810 - accuracy: 0.0000e+00 - val_loss: 0.0761 - val_accuracy: 0.0000e+00
# Epoch 182/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0803 - accuracy: 0.0000e+00 - val_loss: 0.0762 - val_accuracy: 0.0000e+00
# Epoch 183/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0800 - accuracy: 0.0000e+00 - val_loss: 0.0768 - val_accuracy: 0.0000e+00
# Epoch 184/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0803 - accuracy: 0.0000e+00 - val_loss: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 185/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0802 - accuracy: 0.0000e+00 - val_loss: 0.0768 - val_accuracy: 0.0000e+00
# Epoch 186/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0803 - accuracy: 0.0000e+00 - val_loss: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 187/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0797 - accuracy: 0.0000e+00 - val_loss: 0.0764 - val_accuracy: 0.0000e+00
# Epoch 188/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0797 - accuracy: 0.0000e+00 - val_loss: 0.0767 - val_accuracy: 0.0000e+00
# Epoch 189/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0794 - accuracy: 0.0000e+00 - val_loss: 0.0768 - val_accuracy: 0.0000e+00
# Epoch 190/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.0000e+00 - val_loss: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 191/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0783 - accuracy: 0.0000e+00 - val_loss: 0.0764 - val_accuracy: 0.0000e+00
# Epoch 192/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0786 - accuracy: 0.0000e+00 - val_loss: 0.0762 - val_accuracy: 0.0000e+00
# Epoch 193/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0785 - accuracy: 0.0000e+00 - val_loss: 0.0761 - val_accuracy: 0.0000e+00
# Epoch 194/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0793 - accuracy: 0.0000e+00 - val_loss: 0.0759 - val_accuracy: 0.0000e+00
# Epoch 195/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0781 - accuracy: 0.0000e+00 - val_loss: 0.0760 - val_accuracy: 0.0000e+00
# Epoch 196/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.0000e+00 - val_loss: 0.0766 - val_accuracy: 0.0000e+00
# Epoch 197/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.0000e+00 - val_loss: 0.0786 - val_accuracy: 0.0000e+00
# Epoch 198/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0777 - accuracy: 0.0000e+00 - val_loss: 0.0786 - val_accuracy: 0.0000e+00
# Epoch 199/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0772 - accuracy: 0.0000e+00 - val_loss: 0.0786 - val_accuracy: 0.0000e+00
# Epoch 200/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0770 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 201/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0768 - accuracy: 0.0000e+00 - val_loss: 0.0780 - val_accuracy: 0.0000e+00
# Epoch 202/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.0000e+00 - val_loss: 0.0789 - val_accuracy: 0.0000e+00
# Epoch 203/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0765 - accuracy: 0.0000e+00 - val_loss: 0.0783 - val_accuracy: 0.0000e+00
# Epoch 204/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0782 - accuracy: 0.0000e+00 - val_loss: 0.0770 - val_accuracy: 0.0000e+00
# Epoch 205/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0760 - accuracy: 0.0000e+00 - val_loss: 0.0776 - val_accuracy: 0.0000e+00
# Epoch 206/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0765 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 207/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0762 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 208/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.0000e+00 - val_loss: 0.0781 - val_accuracy: 0.0000e+00
# Epoch 209/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0765 - accuracy: 0.0000e+00 - val_loss: 0.0787 - val_accuracy: 0.0000e+00
# Epoch 210/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0759 - accuracy: 0.0000e+00 - val_loss: 0.0778 - val_accuracy: 0.0000e+00
# Epoch 211/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0756 - accuracy: 0.0000e+00 - val_loss: 0.0778 - val_accuracy: 0.0000e+00
# Epoch 212/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.0000e+00 - val_loss: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 213/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0758 - accuracy: 0.0000e+00 - val_loss: 0.0782 - val_accuracy: 0.0000e+00
# Epoch 214/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0760 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 215/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 216/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0756 - accuracy: 0.0000e+00 - val_loss: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 217/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0753 - accuracy: 0.0000e+00 - val_loss: 0.0780 - val_accuracy: 0.0000e+00
# Epoch 218/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.0000e+00 - val_loss: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 219/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0746 - accuracy: 0.0000e+00 - val_loss: 0.0780 - val_accuracy: 0.0000e+00
# Epoch 220/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0757 - accuracy: 0.0000e+00 - val_loss: 0.0784 - val_accuracy: 0.0000e+00
# Epoch 221/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.0000e+00 - val_loss: 0.0784 - val_accuracy: 0.0000e+00
# Epoch 222/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0753 - accuracy: 0.0000e+00 - val_loss: 0.0787 - val_accuracy: 0.0000e+00
# Epoch 223/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.0000e+00 - val_loss: 0.0787 - val_accuracy: 0.0000e+00
# Epoch 224/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0752 - accuracy: 0.0000e+00 - val_loss: 0.0794 - val_accuracy: 0.0000e+00
# Epoch 225/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0744 - accuracy: 0.0000e+00 - val_loss: 0.0794 - val_accuracy: 0.0000e+00
# Epoch 226/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0743 - accuracy: 0.0000e+00 - val_loss: 0.0790 - val_accuracy: 0.0000e+00
# Epoch 227/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0749 - accuracy: 0.0000e+00 - val_loss: 0.0788 - val_accuracy: 0.0000e+00
# Epoch 228/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0748 - accuracy: 0.0000e+00 - val_loss: 0.0790 - val_accuracy: 0.0000e+00
# Epoch 229/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0743 - accuracy: 0.0000e+00 - val_loss: 0.0791 - val_accuracy: 0.0000e+00
# Epoch 230/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.0000e+00 - val_loss: 0.0792 - val_accuracy: 0.0000e+00
# Epoch 231/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0740 - accuracy: 0.0000e+00 - val_loss: 0.0793 - val_accuracy: 0.0000e+00
# Epoch 232/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0738 - accuracy: 0.0000e+00 - val_loss: 0.0795 - val_accuracy: 0.0000e+00
# Epoch 233/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0738 - accuracy: 0.0000e+00 - val_loss: 0.0798 - val_accuracy: 0.0000e+00
# Epoch 234/20000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0737 - accuracy: 0.0000e+00 - val_loss: 0.0795 - val_accuracy: 0.0000e+00
# Epoch 235/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0738 - accuracy: 0.0000e+00 - val_loss: 0.0795 - val_accuracy: 0.0000e+00
# Epoch 236/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0738 - accuracy: 0.0000e+00 - val_loss: 0.0794 - val_accuracy: 0.0000e+00
# Epoch 237/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0739 - accuracy: 0.0000e+00 - val_loss: 0.0794 - val_accuracy: 0.0000e+00
# Epoch 238/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0741 - accuracy: 0.0000e+00 - val_loss: 0.0795 - val_accuracy: 0.0000e+00
# Epoch 239/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0735 - accuracy: 0.0000e+00 - val_loss: 0.0799 - val_accuracy: 0.0000e+00
# Epoch 240/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0734 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00
# Epoch 241/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0740 - accuracy: 0.0000e+00 - val_loss: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 242/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0742 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00
# Epoch 243/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0737 - accuracy: 0.0000e+00 - val_loss: 0.0817 - val_accuracy: 0.0000e+00
# Epoch 244/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0736 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 245/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 0.0000e+00 - val_loss: 0.0813 - val_accuracy: 0.0000e+00
# Epoch 246/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0734 - accuracy: 0.0000e+00 - val_loss: 0.0813 - val_accuracy: 0.0000e+00
# Epoch 247/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0807 - val_accuracy: 0.0000e+00
# Epoch 248/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0729 - accuracy: 0.0000e+00 - val_loss: 0.0799 - val_accuracy: 0.0000e+00
# Epoch 249/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0729 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 250/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0731 - accuracy: 0.0000e+00 - val_loss: 0.0800 - val_accuracy: 0.0000e+00
# Epoch 251/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0729 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 252/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0801 - val_accuracy: 0.0000e+00
# Epoch 253/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 254/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 255/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0728 - accuracy: 0.0000e+00 - val_loss: 0.0810 - val_accuracy: 0.0000e+00
# Epoch 256/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0732 - accuracy: 0.0000e+00 - val_loss: 0.0814 - val_accuracy: 0.0000e+00
# Epoch 257/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0809 - val_accuracy: 0.0000e+00
# Epoch 258/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.0000e+00 - val_loss: 0.0809 - val_accuracy: 0.0000e+00
# Epoch 259/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0725 - accuracy: 0.0000e+00 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 260/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 261/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0808 - val_accuracy: 0.0000e+00
# Epoch 262/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0808 - val_accuracy: 0.0000e+00
# Epoch 263/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0808 - val_accuracy: 0.0000e+00
# Epoch 264/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 265/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0728 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 266/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0733 - accuracy: 0.0000e+00 - val_loss: 0.0808 - val_accuracy: 0.0000e+00
# Epoch 267/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0728 - accuracy: 0.0000e+00 - val_loss: 0.0807 - val_accuracy: 0.0000e+00
# Epoch 268/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0725 - accuracy: 0.0000e+00 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 269/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 270/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0813 - val_accuracy: 0.0000e+00
# Epoch 271/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0810 - val_accuracy: 0.0000e+00
# Epoch 272/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0811 - val_accuracy: 0.0000e+00
# Epoch 273/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00
# Epoch 274/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0719 - accuracy: 0.0000e+00 - val_loss: 0.0814 - val_accuracy: 0.0000e+00
# Epoch 275/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0807 - val_accuracy: 0.0000e+00
# Epoch 276/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0803 - val_accuracy: 0.0000e+00
# Epoch 277/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 278/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0809 - val_accuracy: 0.0000e+00
# Epoch 279/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0719 - accuracy: 0.0000e+00 - val_loss: 0.0806 - val_accuracy: 0.0000e+00
# Epoch 280/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0807 - val_accuracy: 0.0000e+00
# Epoch 281/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0719 - accuracy: 0.0000e+00 - val_loss: 0.0811 - val_accuracy: 0.0000e+00
# Epoch 282/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00
# Epoch 283/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0817 - val_accuracy: 0.0000e+00
# Epoch 284/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0714 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 285/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0714 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 286/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0815 - val_accuracy: 0.0000e+00
# Epoch 287/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0833 - val_accuracy: 0.0000e+00
# Epoch 288/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0833 - val_accuracy: 0.0000e+00
# Epoch 289/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0719 - accuracy: 0.0000e+00 - val_loss: 0.0832 - val_accuracy: 0.0000e+00
# Epoch 290/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0719 - accuracy: 0.0000e+00 - val_loss: 0.0829 - val_accuracy: 0.0000e+00
# Epoch 291/20000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0817 - val_accuracy: 0.0000e+00
# Epoch 292/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0715 - accuracy: 0.0000e+00 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 293/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0807 - val_accuracy: 0.0000e+00
# Epoch 294/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0810 - val_accuracy: 0.0000e+00
# Epoch 295/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0811 - val_accuracy: 0.0000e+00
# Epoch 296/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0712 - accuracy: 0.0000e+00 - val_loss: 0.0812 - val_accuracy: 0.0000e+00
# Epoch 297/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0717 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 298/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0713 - accuracy: 0.0000e+00 - val_loss: 0.0822 - val_accuracy: 0.0000e+00
# Epoch 299/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0819 - val_accuracy: 0.0000e+00
# Epoch 300/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 301/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 302/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0712 - accuracy: 0.0000e+00 - val_loss: 0.0815 - val_accuracy: 0.0000e+00
# Epoch 303/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0820 - val_accuracy: 0.0000e+00
# Epoch 304/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.0000e+00 - val_loss: 0.0822 - val_accuracy: 0.0000e+00
# Epoch 305/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0828 - val_accuracy: 0.0000e+00
# Epoch 306/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0716 - accuracy: 0.0000e+00 - val_loss: 0.0818 - val_accuracy: 0.0000e+00
# Epoch 307/20000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0713 - accuracy: 0.0000e+00 - val_loss: 0.0819 - val_accuracy: 0.0000e+00
# Epoch 308/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0713 - accuracy: 0.0000e+00 - val_loss: 0.0826 - val_accuracy: 0.0000e+00
# Epoch 309/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.0000e+00 - val_loss: 0.0822 - val_accuracy: 0.0000e+00
# Epoch 310/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0708 - accuracy: 0.0000e+00 - val_loss: 0.0820 - val_accuracy: 0.0000e+00
# Epoch 311/20000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0712 - accuracy: 0.0000e+00 - val_loss: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 312/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.
20000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2664e-04 - accuracy: 0.0312 - val_loss: 0.0884 - val_accuracy: 0.0000e+00
# Epoch 19971/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9223e-04 - accuracy: 0.0312 - val_loss: 0.0930 - val_accuracy: 0.0000e+00
# Epoch 19972/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.7973e-04 - accuracy: 0.0312 - val_loss: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 19973/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.7232e-04 - accuracy: 0.0312 - val_loss: 0.0909 - val_accuracy: 0.0000e+00
# Epoch 19974/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6242e-04 - accuracy: 0.0312 - val_loss: 0.0902 - val_accuracy: 0.0000e+00
# Epoch 19975/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1747e-04 - accuracy: 0.0312 - val_loss: 0.0916 - val_accuracy: 0.0000e+00
# Epoch 19976/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.3567e-04 - accuracy: 0.0312 - val_loss: 0.0896 - val_accuracy: 0.0000e+00
# Epoch 19977/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 2.4534e-04 - accuracy: 0.0312 - val_loss: 0.0924 - val_accuracy: 0.0000e+00
# Epoch 19978/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.2549e-04 - accuracy: 0.0312 - val_loss: 0.0886 - val_accuracy: 0.0000e+00
# Epoch 19979/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1320e-04 - accuracy: 0.0312 - val_loss: 0.0903 - val_accuracy: 0.0000e+00
# Epoch 19980/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9624e-04 - accuracy: 0.0312 - val_loss: 0.0889 - val_accuracy: 0.0000e+00
# Epoch 19981/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1758e-04 - accuracy: 0.0312 - val_loss: 0.0919 - val_accuracy: 0.0000e+00
# Epoch 19982/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 4.0068e-04 - accuracy: 0.0312 - val_loss: 0.0890 - val_accuracy: 0.0000e+00
# Epoch 19983/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 4.7377e-04 - accuracy: 0.0312 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 19984/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 4.7657e-04 - accuracy: 0.0312 - val_loss: 0.0832 - val_accuracy: 0.0000e+00
# Epoch 19985/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 8.8574e-04 - accuracy: 0.0312 - val_loss: 0.0980 - val_accuracy: 0.0000e+00
# Epoch 19986/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 0.0312 - val_loss: 0.0898 - val_accuracy: 0.0000e+00
# Epoch 19987/20000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.0312 - val_loss: 0.0972 - val_accuracy: 0.0000e+00
# Epoch 19988/20000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.0312 - val_loss: 0.0869 - val_accuracy: 0.0000e+00
# Epoch 19989/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.0312 - val_loss: 0.0991 - val_accuracy: 0.0000e+00
# Epoch 19990/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.0312 - val_loss: 0.0863 - val_accuracy: 0.0000e+00
# Epoch 19991/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.0312 - val_loss: 0.0981 - val_accuracy: 0.0000e+00
# Epoch 19992/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.0312 - val_loss: 0.0875 - val_accuracy: 0.0000e+00
# Epoch 19993/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 7.2648e-04 - accuracy: 0.0312 - val_loss: 0.1046 - val_accuracy: 0.0000e+00
# Epoch 19994/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 0.0312 - val_loss: 0.0896 - val_accuracy: 0.0000e+00
# Epoch 19995/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.0312 - val_loss: 0.0900 - val_accuracy: 0.0000e+00
# Epoch 19996/20000
# 7/7 [==============================] - 0s 5ms/step - loss: 6.6528e-04 - accuracy: 0.0312 - val_loss: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 19997/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 9.1503e-04 - accuracy: 0.0312 - val_loss: 0.0877 - val_accuracy: 0.0000e+00
# Epoch 19998/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 7.3871e-04 - accuracy: 0.0312 - val_loss: 0.0931 - val_accuracy: 0.0000e+00
# Epoch 19999/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 5.6961e-04 - accuracy: 0.0312 - val_loss: 0.0914 - val_accuracy: 0.0000e+00
# Epoch 20000/20000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.5894e-04 - accuracy: 0.0312 - val_loss: 0.0871 - val_accuracy: 0.0000e+00

# %% [markdown]
# #### Visualize the Overfit
#
# Now we can visualize our overfit model.

# %%
pred_norm_Nporsity = model_3(tf.convert_to_tensor(norm_depth_bins.reshape([-1,1]))).numpy().flatten() # predict with our ANN
pred_Nporosity = ((pred_norm_Nporsity + 1)/2*(Npor_max - Npor_min)+Npor_min)

plt.subplot(1,1,1)
plt.plot(depth_bins,pred_Nporosity,'black',linewidth=2)
plt.plot(X2_train['Depth'].values,y2_train['Nporosity'].values, 'o', markerfacecolor='red', markeredgecolor='black', alpha=1.0, label = "Train")
plt.plot(X2_test['Depth'].values,y2_test['Nporosity'].values, 'o', markerfacecolor='blue', markeredgecolor='black', alpha=1.0, label = "Test")
plt.xlabel('Depth (m)')
plt.ylabel('Porosity (faction)')
plt.legend()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# #### Visualize the Training and Testing Error
#
# Let's visualize the training and testing error over the training epochs.

# %%
# Plot the Loss vs. Training Epoch 
plt.subplot(1,1,1)
plt.plot(hist3.history['loss'])
plt.plot(hist3.history['val_loss'])
plt.title('Loss function of Artificial Neural Net Example #2')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0,0.4)
plt.grid()
plt.tight_layout()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2.0, top=0.8, wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# We can observe the weights and bias terms associate with our neural network.
#
# #### Comments
#
# This was a basic demonstration of artificial neural networks.
#
# The Texas Center for Geostatistics has many other demonstrations on the basics of working with DataFrames, ndarrays, univariate statistics, plotting data, declustering, data transformations, trend modeling and many other workflows available [here](https://github.com/GeostatsGuy/PythonNumericalDemos), along with a package for geostatistics in Python called [GeostatsPy](https://github.com/GeostatsGuy/GeostatsPy).
#
# We hope this was helpful,
#
# *Michael* and *Honggeun*
#
# ***
#
# #### More on Michael Pyrcz and the Texas Center for Data Analytics and Geostatistics:
#
# ### Michael Pyrcz, Associate Professor, University of Texas at Austin
# *Novel Data Analytics, Geostatistics and Machine Learning Subsurface Solutions*
#
# With over 17 years of experience in subsurface consulting, research and development, Michael has returned to academia driven by his passion for teaching and enthusiasm for enhancing engineers' and geoscientists' impact in subsurface resource development.
#
# For more about Michael check out these links:
#
# #### [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
#
# #### Want to Work Together?
#
# I hope this content is helpful to those that want to learn more about subsurface modeling, data analytics and machine learning. Students and working professionals are welcome to participate.
#
# * Want to invite me to visit your company for training, mentoring, project review, workflow design and / or consulting? I'd be happy to drop by and work with you!
#
# * Interested in partnering, supporting my graduate student research or my Subsurface Data Analytics and Machine Learning consortium (co-PIs including Profs. Foster, Torres-Verdin and van Oort)? My research combines data analytics, stochastic modeling and machine learning theory with practice to develop novel methods and workflows to add value. We are solving challenging subsurface problems!
#
# * I can be reached at mpyrcz@austin.utexas.edu.
#
# I'm always happy to discuss,
#
# *Michael*
#
# Michael Pyrcz, Ph.D., P.Eng. Associate Professor The Hildebrand Department of Petroleum and Geosystems Engineering, Bureau of Economic Geology, The Jackson School of Geosciences, The University of Texas at Austin
#
# #### More Resources Available at: [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
